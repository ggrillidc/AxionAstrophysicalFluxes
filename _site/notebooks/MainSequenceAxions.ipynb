# %% [markdown]
# # Main Sequence axion emission
#
#
# The quasi-thermal Main Sequence stars axion spectrum at the source can be parametrized by:
# \begin{equation}
# \frac{d\Phi_a}{dE_a}= C_0 \left(\frac{g_{ax}}{g_{\mathrm{ref}}}\right)^2 \left(\frac{E}{E_0}\right)^\beta e^{-(1+\beta)\frac{E}{E_0}}
# \end{equation}
# where the axion parameters are shown in following Table.

# %%
from Axion_fluxes import plot_MainSequenceAxion_flux
plot_MainSequenceAxion_flux('Primakoff', 0, 30)

# %%
plot_MainSequenceAxion_flux('Bremsstrahlung', 0, 20)

# %%
plot_MainSequenceAxion_flux('Compton', 0, 40)
